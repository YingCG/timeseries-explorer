# %%
import pandas as pd
nzrain = pd.read_csv('./data/NOAA.csv')
nzrain.head()
# Out:
# C:\Users\yingg\AppData\Local\Temp\ipykernel_25292\1712116904.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   nzrain = pd.read_csv('./data/NOAA.csv')
#        STATION                     NAME        DATE  PRCP PRCP_ATTRIBUTES
# 0  NZ000939870  CHATHAM ISLANDS AWS, NZ  1960-03-05   NaN             NaN  \
# 1  NZ000939870  CHATHAM ISLANDS AWS, NZ  1960-03-06   NaN             NaN
# 2  NZ000939870  CHATHAM ISLANDS AWS, NZ  1960-03-07   NaN             NaN
# 3  NZ000939870  CHATHAM ISLANDS AWS, NZ  1960-03-08   NaN             NaN
# 4  NZ000939870  CHATHAM ISLANDS AWS, NZ  1960-03-09   NaN             NaN
#
#    SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES  TMIN
# 0   NaN             NaN   NaN             NaN  57.0             ,,G  51.0  \
# 1   NaN             NaN   NaN             NaN  60.0             ,,G  52.0
# 2   NaN             NaN   NaN             NaN  61.0             ,,G  53.0
# ...

# %%
auck_rain = nzrain[nzrain['NAME'] == 'AUCKLAND AERO AWS, NZ']
auck_rain.head()
# Out:
#             STATION                   NAME        DATE  PRCP PRCP_ATTRIBUTES
# 193592  NZM00093110  AUCKLAND AERO AWS, NZ  1994-08-02   NaN             NaN  \
# 193593  NZM00093110  AUCKLAND AERO AWS, NZ  1994-08-03   NaN             NaN
# 193594  NZM00093110  AUCKLAND AERO AWS, NZ  1994-08-04  0.00             ,,S
# 193595  NZM00093110  AUCKLAND AERO AWS, NZ  1994-08-05  0.02             ,,S
# 193596  NZM00093110  AUCKLAND AERO AWS, NZ  1994-08-06  0.00             ,,S
#
#         SNWD SNWD_ATTRIBUTES  TAVG TAVG_ATTRIBUTES  TMAX TMAX_ATTRIBUTES
# 193592   NaN             NaN  56.0            H,,S   NaN             NaN  \
# 193593   NaN             NaN  55.0            H,,S   NaN             NaN
# 193594   NaN             NaN  52.0            H,,S   NaN             NaN
# 193595   NaN             NaN  54.0            H,,S   NaN             NaN
# 193596   NaN             NaN  53.0            H,,S   NaN             NaN
#
#         TMIN TMIN_ATTRIBUTES
# 193592   NaN             NaN
# ...

# %%
auck_rain = auck_rain.drop(columns=['STATION', 'NAME','PRCP_ATTRIBUTES', 'SNWD_ATTRIBUTES', 'TAVG_ATTRIBUTES', 'TMAX_ATTRIBUTES', 'TMIN_ATTRIBUTES'] )
auck_rain.head()
# Out:
#               DATE  PRCP  SNWD  TAVG  TMAX  TMIN
# 193592  1994-08-02   NaN   NaN  56.0   NaN   NaN
# 193593  1994-08-03   NaN   NaN  55.0   NaN   NaN
# 193594  1994-08-04  0.00   NaN  52.0   NaN   NaN
# 193595  1994-08-05  0.02   NaN  54.0   NaN   NaN
# 193596  1994-08-06  0.00   NaN  53.0   NaN   NaN

# %%
auck_rain['DATE'] = pd.to_datetime(auck_rain['DATE'])
print(auck_rain.columns)
# Out:
# Index(['DATE', 'PRCP', 'SNWD', 'TAVG', 'TMAX', 'TMIN'], dtype='object')
